# %%
import scipy.optimize as optimize

# %%
def f(x):
     
    x1 = x[0]
    x2 = x[1]
    pwr = abs(100 - (((x1**2 + x2**2)**0.5)/3.14159))
    inner = abs(np.sin(x1)*np.sin(x2)*(2.718281**pwr))
    outer = -0.0001*((inner-1)**0.1)
    return outer

bnds = ((-10, 10), (-10, 10))

# %%
res = optimize.minimize(fun=f,x0=[-1.0,1.0],method='L-BFGS-B',bounds=bnds)
print(res.fun)
print(res.x)
# Out:
# -2.062605516810367
# [-1.3493853   1.34938658]

# %%
# Implementation of matplotlib function
import matplotlib.pyplot as plt
import numpy as np
  
feature_x = np.arange(-10, 10, 0.05)
feature_y = np.arange(-10, 10, 0.05)
  
# Creating 2-D grid of features
[x, y] = np.meshgrid(feature_x, feature_y)
  
fig, ax = plt.subplots(1, 1)
  

pwr = abs(100 - (((x**2 + y**2)**0.5)/3.14159))
inner = abs(np.sin(x)*np.sin(y)*(2.718281**pwr))
outer = -0.0001*((inner-1)**0.1)

'''
f1 = (1-x+(x*y))**2
f2 = (2-x+((x**2)*y))**2
f3 = (3-x+((x**3)*y))**2
outer = f1+f2+f3
''' 
# plots contour lines
ax.contour(x, y, outer)
  
ax.set_title('Contour Plot')
ax.set_xlabel('feature_x')
ax.set_ylabel('feature_y')
  
plt.show()
